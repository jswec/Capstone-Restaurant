# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 9A45-0C78
#
#  Directory of C:\Users\Jake\Documents\CapstoneTransplant\Capstone-Restaurant
#
# 04/11/2023  06:53 AM    <DIR>          .
# 04/11/2023  04:07 AM    <DIR>          ..
# 04/11/2023  04:17 AM             1,942 .gitignore
# 04/11/2023  04:19 AM    <DIR>          .ipynb_checkpoints
# 04/11/2023  06:48 AM    <DIR>          Data
# 04/11/2023  06:53 AM            36,783 First.ipynb
# 04/11/2023  04:07 AM                23 README.md
#                3 File(s)         38,748 bytes
#                4 Dir(s)  85,666,619,392 bytes free

# %%
import sqlite3
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
import json
import argparse
import collections
import csv
plt.style.use('seaborn-notebook')
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import euclidean

# %%
df = pd.read_csv('Data/yelp_business.csv')
df = pd.DataFrame(df)

# %%
df = pd.DataFrame(df)

# %%
df2 = pd.read_csv('Data/yelp_business_attributes.csv')

# %%
df2
merged_df = pd.merge(df, df2, on='business_id')
merged_df
# Out:
#                    business_id                           name  \
# 0       FYWN1wneV18bWNgQjJ2GNg             "Dental by Design"
# 1       He-G7vWjzVUysIKrfNbPUQ          "Stephen Szabo Salon"
# 2       8DShNS-LuFqpEWIp0HxijA             "Sports Authority"
# 3       PfOCPjBrlQAnz__NXj9h_w     "Brick House Tavern + Tap"
# 4       o9eMRCWt5PkpLDE0gOPtcQ                      "Messina"
# ...                        ...                            ...
# 152036  kLFm_kehXNZkUc1oa2-Eaw         "Nuno's Churrasqueira"
# 152037  gRGalHVu6BcaUDIAGVW_xQ            "Village Auto Body"
# 152038  XXvZBIHoJBU5d6-a-oyMWQ                          "AAM"
# 152039  lNpPGgM96nPIYM1shxciHg  "Bronze Beauty Spray Tanning"
# 152040  viKaP26BcHU6cLx8sf4gKg             "Phoenix Pharmacy"
#
#             neighborhood                           address            city  \
# 0                    NaN        "4855 E Warner Rd, Ste B9"       Ahwatukee
# 1                    NaN              "3101 Washington Rd"        McMurray
# 2                    NaN  "5000 Arizona Mills Cr, Ste 435"           Tempe
# 3                    NaN                    "581 Howe Ave"  Cuyahoga Falls
# 4                    NaN                  "Richterstr. 11"       Stuttgart
# ...                  ...                               ...             ...
# 152036  Brockton Village                "1560 Dundas St W"         Toronto
# 152037               NaN             "3957 Brecksville Rd"       Richfield
# 152038               NaN     "1600 W Broadway Rd, Ste 200"           Tempe
# 152039               NaN      "300 Camp Horne Rd, Ste 250"      Pittsburgh
# 152040               NaN    "1701 East Thomas Rd, Ste 105"         Phoenix
#
#        state postal_code   latitude   longitude  stars  ...  Corkage  \
# 0         AZ       85044  33.330690 -111.978599    4.0  ...       Na
# 1         PA       15317  40.291685  -80.104900    3.0  ...       Na
# 2         AZ       85282  33.383147 -111.964725    3.0  ...       Na
# 3         OH       44221  41.119535  -81.475690    3.5  ...       Na
# 4         BW       70567  48.727200    9.147950    4.0  ...       Na
# ...      ...         ...        ...         ...    ...  ...      ...
# 152036    ON     M6K 1T5  43.649789  -79.433928    3.0  ...       Na
# 152037    OH       44286  41.243385  -81.636212    5.0  ...       Na
# 152038    AZ       85282  33.407914 -111.965098    1.5  ...       Na
# 152039    PA       15202  40.517724  -80.091466    5.0  ...       Na
# 152040    AZ       85016  33.479861 -112.044689    5.0  ...       Na
#
#         DietaryRestrictions_dairy-free DietaryRestrictions_gluten-free  \
# 0                                   Na                              Na
# 1                                   Na                              Na
# 2                                   Na                              Na
# 3                                   Na                              Na
# 4                                   Na                              Na
# ...                                ...                             ...
# 152036                              Na                              Na
# 152037                              Na                              Na
# 152038                              Na                              Na
# 152039                              Na                              Na
# 152040                              Na                              Na
#
#        DietaryRestrictions_vegan DietaryRestrictions_kosher  \
# 0                             Na                         Na
# 1                             Na                         Na
# 2                             Na                         Na
# 3                             Na                         Na
# 4                             Na                         Na
# ...                          ...                        ...
# 152036                        Na                         Na
# 152037                        Na                         Na
# 152038                        Na                         Na
# 152039                        Na                         Na
# 152040                        Na                         Na
#
#        DietaryRestrictions_halal DietaryRestrictions_soy-free  \
# 0                             Na                           Na
# 1                             Na                           Na
# 2                             Na                           Na
# 3                             Na                           Na
# 4                             Na                           Na
# ...                          ...                          ...
# 152036                        Na                           Na
# 152037                        Na                           Na
# 152038                        Na                           Na
# 152039                        Na                           Na
# 152040                        Na                           Na
#
#        DietaryRestrictions_vegetarian AgesAllowed RestaurantsCounterService
# 0                                  Na          Na                        Na
# 1                                  Na          Na                        Na
# 2                                  Na          Na                        Na
# 3                                  Na          Na                        Na
# 4                                  Na          Na                        Na
# ...                               ...         ...                       ...
# 152036                             Na          Na                        Na
# 152037                             Na          Na                        Na
# 152038                             Na          Na                        Na
# 152039                             Na          Na                        Na
# 152040                             Na          Na                        Na
#
# [152041 rows x 94 columns]

# %%
city_counts = merged_df['city'].value_counts()
state_counts = merged_df['state'].value_counts()
city_counts
# Out:
# Las Vegas                 26775
# Phoenix                   17213
# Toronto                   17206
# Charlotte                  8553
# Scottsdale                 8228
#                           ...
# St-Lazare-de-Vaudreuil        1
# oakville                      1
# Scottsdale, AZ                1
# Crescent                      1
# Chomedey, Laval               1
# Name: city, Length: 1093, dtype: int64

# %%
state_counts
# Out:
# AZ     52214
# NV     33086
# ON     30208
# NC     12956
# OH     12609
#        ...
# NLK        1
# WA         1
# ZET        1
# AB         1
# PKN        1
# Name: state, Length: 67, dtype: int64

# %%
allowed_values = ['NC', 'OH']

# %%
df_filtered = merged_df[merged_df['state'].isin(allowed_values)]

# %%
merged_df
# Out:
#                    business_id                           name  \
# 0       FYWN1wneV18bWNgQjJ2GNg             "Dental by Design"
# 1       He-G7vWjzVUysIKrfNbPUQ          "Stephen Szabo Salon"
# 2       8DShNS-LuFqpEWIp0HxijA             "Sports Authority"
# 3       PfOCPjBrlQAnz__NXj9h_w     "Brick House Tavern + Tap"
# 4       o9eMRCWt5PkpLDE0gOPtcQ                      "Messina"
# ...                        ...                            ...
# 152036  kLFm_kehXNZkUc1oa2-Eaw         "Nuno's Churrasqueira"
# 152037  gRGalHVu6BcaUDIAGVW_xQ            "Village Auto Body"
# 152038  XXvZBIHoJBU5d6-a-oyMWQ                          "AAM"
# 152039  lNpPGgM96nPIYM1shxciHg  "Bronze Beauty Spray Tanning"
# 152040  viKaP26BcHU6cLx8sf4gKg             "Phoenix Pharmacy"
#
#             neighborhood                           address            city  \
# 0                    NaN        "4855 E Warner Rd, Ste B9"       Ahwatukee
# 1                    NaN              "3101 Washington Rd"        McMurray
# 2                    NaN  "5000 Arizona Mills Cr, Ste 435"           Tempe
# 3                    NaN                    "581 Howe Ave"  Cuyahoga Falls
# 4                    NaN                  "Richterstr. 11"       Stuttgart
# ...                  ...                               ...             ...
# 152036  Brockton Village                "1560 Dundas St W"         Toronto
# 152037               NaN             "3957 Brecksville Rd"       Richfield
# 152038               NaN     "1600 W Broadway Rd, Ste 200"           Tempe
# 152039               NaN      "300 Camp Horne Rd, Ste 250"      Pittsburgh
# 152040               NaN    "1701 East Thomas Rd, Ste 105"         Phoenix
#
#        state postal_code   latitude   longitude  stars  ...  Corkage  \
# 0         AZ       85044  33.330690 -111.978599    4.0  ...       Na
# 1         PA       15317  40.291685  -80.104900    3.0  ...       Na
# 2         AZ       85282  33.383147 -111.964725    3.0  ...       Na
# 3         OH       44221  41.119535  -81.475690    3.5  ...       Na
# 4         BW       70567  48.727200    9.147950    4.0  ...       Na
# ...      ...         ...        ...         ...    ...  ...      ...
# 152036    ON     M6K 1T5  43.649789  -79.433928    3.0  ...       Na
# 152037    OH       44286  41.243385  -81.636212    5.0  ...       Na
# 152038    AZ       85282  33.407914 -111.965098    1.5  ...       Na
# 152039    PA       15202  40.517724  -80.091466    5.0  ...       Na
# 152040    AZ       85016  33.479861 -112.044689    5.0  ...       Na
#
#         DietaryRestrictions_dairy-free DietaryRestrictions_gluten-free  \
# 0                                   Na                              Na
# 1                                   Na                              Na
# 2                                   Na                              Na
# 3                                   Na                              Na
# 4                                   Na                              Na
# ...                                ...                             ...
# 152036                              Na                              Na
# 152037                              Na                              Na
# 152038                              Na                              Na
# 152039                              Na                              Na
# 152040                              Na                              Na
#
#        DietaryRestrictions_vegan DietaryRestrictions_kosher  \
# 0                             Na                         Na
# 1                             Na                         Na
# 2                             Na                         Na
# 3                             Na                         Na
# 4                             Na                         Na
# ...                          ...                        ...
# 152036                        Na                         Na
# 152037                        Na                         Na
# 152038                        Na                         Na
# 152039                        Na                         Na
# 152040                        Na                         Na
#
#        DietaryRestrictions_halal DietaryRestrictions_soy-free  \
# 0                             Na                           Na
# 1                             Na                           Na
# 2                             Na                           Na
# 3                             Na                           Na
# 4                             Na                           Na
# ...                          ...                          ...
# 152036                        Na                           Na
# 152037                        Na                           Na
# 152038                        Na                           Na
# 152039                        Na                           Na
# 152040                        Na                           Na
#
#        DietaryRestrictions_vegetarian AgesAllowed RestaurantsCounterService
# 0                                  Na          Na                        Na
# 1                                  Na          Na                        Na
# 2                                  Na          Na                        Na
# 3                                  Na          Na                        Na
# 4                                  Na          Na                        Na
# ...                               ...         ...                       ...
# 152036                             Na          Na                        Na
# 152037                             Na          Na                        Na
# 152038                             Na          Na                        Na
# 152039                             Na          Na                        Na
# 152040                             Na          Na                        Na
#
# [152041 rows x 94 columns]

# %%
columns_to_drop = ['neighborhood', 'is_open', 'address', 'business_id', 'city', 'postal_code', 'latitude', 'longitude']

# %%
df_filtered = df_filtered.drop(columns_to_drop, axis=1)

# %%
df_filtered
# Out:
#                                    name state  stars  review_count  \
# 4            "Brick House Tavern + Tap"    OH    3.5           116
# 14         "Showmars Government Center"    NC    3.5             7
# 28                       "Panera Bread"    OH    2.0             4
# 35                     "Brewster's Pub"    OH    4.0             4
# 38                          "By Design"    NC    2.5             3
# ...                                 ...   ...    ...           ...
# 174509            "Asian Health Center"    OH    5.0             3
# 174516  "Carlone's Candy and Ice Cream"    OH    4.0             3
# 174532            "Cole's Public House"    OH    4.5            21
# 174553                            "CVS"    NC    2.0             5
# 174563              "Village Auto Body"    OH    5.0             3
#
#                                                categories
# 4       American (New);Nightlife;Bars;Sandwiches;Ameri...
# 14                     Restaurants;American (Traditional)
# 28                      Soup;Salad;Sandwiches;Restaurants
# 35                                    Nightlife;Pubs;Bars
# 38                Home & Garden;Furniture Stores;Shopping
# ...                                                   ...
# 174509                       Acupuncture;Health & Medical
# 174516  Cooking Schools;Specialty Schools;Food;Educati...
# 174532  Bars;Gastropubs;Nightlife;Restaurants;Pubs;San...
# 174553                                Drugstores;Shopping
# 174563                              Body Shops;Automotive
#
# [25565 rows x 5 columns]

# %%
df_filtered.describe
# Out:
# <bound method NDFrame.describe of                                    name state  stars  review_count  \
# 4            "Brick House Tavern + Tap"    OH    3.5           116
# 14         "Showmars Government Center"    NC    3.5             7
# 28                       "Panera Bread"    OH    2.0             4
# 35                     "Brewster's Pub"    OH    4.0             4
# 38                          "By Design"    NC    2.5             3
# ...                                 ...   ...    ...           ...
# 174509            "Asian Health Center"    OH    5.0             3
# 174516  "Carlone's Candy and Ice Cream"    OH    4.0             3
# 174532            "Cole's Public House"    OH    4.5            21
# 174553                            "CVS"    NC    2.0             5
# 174563              "Village Auto Body"    OH    5.0             3
#
#                                                categories
# 4       American (New);Nightlife;Bars;Sandwiches;Ameri...
# 14                     Restaurants;American (Traditional)
# 28                      Soup;Salad;Sandwiches;Restaurants
# 35                                    Nightlife;Pubs;Bars
# 38                Home & Garden;Furniture Stores;Shopping
# ...                                                   ...
# 174509                       Acupuncture;Health & Medical
# 174516  Cooking Schools;Specialty Schools;Food;Educati...
# 174532  Bars;Gastropubs;Nightlife;Restaurants;Pubs;San...
# 174553                                Drugstores;Shopping
# 174563                              Body Shops;Automotive
#
# [25565 rows x 5 columns]>

# %%
Dolce = df_filtered[df_filtered['name'] == '"Dolce Vita Wine Bar"']
print(Dolce)
# Out:
#                        name state  stars  review_count  \
# 1959  "Dolce Vita Wine Bar"    NC    4.0            53
#
#                                              categories
# 1959  Wine Bars;Cocktail Bars;Beer;Wine & Spirits;Pi...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-61e199b6920b> in <module>
# ----> 1 distances = df_filtered.apply(lambda row: euclidean(row, chosen_row), axis=1)
#       2 similar_indices = distances.argsort()[1:]
#       3 similar_rows = df_filtered.iloc[similar_indices]
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-177-61e199b6920b> in <lambda>(row)
# ----> 1 distances = df_filtered.apply(lambda row: euclidean(row, chosen_row), axis=1)
#       2 similar_indices = distances.argsort()[1:]
#       3 similar_rows = df_filtered.iloc[similar_indices]
#
# ~\anaconda3\envs\learn-env\lib\site-packages\scipy\spatial\distance.py in euclidean(u, v, w)
#     612
#     613     """
# --> 614     return minkowski(u, v, p=2, w=w)
#     615
#     616
#
# ~\anaconda3\envs\learn-env\lib\site-packages\scipy\spatial\distance.py in minkowski(u, v, p, w)
#     504     if p < 1:
#     505         raise ValueError("p must be at least 1")
# --> 506     u_v = u - v
#     507     if w is not None:
#     508         w = _validate_weights(w)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
